# %%
import requests
from lxml import etree
import re

# %%
id_licitacion = "4127-83-LR24" # no sé cómo convertirlo a url (no es base64)
url = "https://www.mercadopublico.cl/Procurement/Modules/RFB/DetailsAcquisition.aspx?qs=uJfqrJbBFceKUZ/ugOAghQ=="
response = requests.get(url)

# %%
parser = etree.HTMLParser()
tree = etree.fromstring(response.text, parser)
print(etree.tostring(tree, pretty_print=True, method='html')) # HTML completo
# Out:
# b'<html xmlns="http://www.w3.org/1999/xhtml">\r\n<head id="Head2">\r\n\r\n    <style>\r\n        .sustentClass1 {\r\n            font-size: 12px;\r\n            color: #666666;\r\n            font-weight: bolder;\r\n            font-family: "gobCL";\r\n        }\r\n\r\n        .sustentClass2 {\r\n            font-size: 12px;\r\n            color: #666666;\r\n            font-family: "gobCL";\r\n        }\r\n    </style>\r\n\r\n    <meta http-equiv="X-UA-Compatible" content="IE=9">\n<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\n<title>\r\n\tFicha Licitaci&#243;n\r\n</title>\r\n        <script async src="https://www.googletagmanager.com/gtag/js?id=UA-51338325-2"></script>\r\n        \r\n\r\n    \r\n\r\n    <script src="../../Includes/scripts/JQuery/jquery-1.7.2.min.js" type="text/javascript"></script>\r\n    <script src="../../Includes/scripts/JQuery/jquery.blockUI.js" type="text/javascript"></script>\r\n    <!-- Global Site Tag (gtag.js) - Google Analytics -->\r\n   
# ...

# %% [markdown]
# ## Estado licitación

# %%
box_a2 = tree.find(".//body//div[@class='FichaLight']//div[@id='box_a2']")
imgEstado = box_a2.find(".//table//td//img[@id='imgEstado']")
print(imgEstado.get('src')) # Url imagen :D
estado = re.match(r".*/([^/]+).png$", imgEstado.get('src')).group(1)
print("Estado:", estado) # Estado
# Out:
# ../../Includes/images/FichaLight/iconos_estados/desierta.png
# Estado: desierta

# %% [markdown]
# ## Adjuntos

# %%
box_b = tree.find(".//body//div[@id='box_b']")
imgAdjuntos = box_b.find(".//input[@id='imgAdjuntos']")
enc_adjuntos = re.match(r".*enc=([^']+)'.*", imgAdjuntos.get('onclick')).group(1)
print(enc_adjuntos) # varía cada vez que se obtiene la página de la licitación
url_adjuntos = f"https://www.mercadopublico.cl/Procurement/Modules/Attachment/ViewAttachment.aspx?enc={enc_adjuntos}"
print(url_adjuntos)
# Out:
# flAJmJr7x%2bRNbpyFdPxErlTsgbcPbJ0B5MgcnreBjKM8k9WdB1kQ9ti84F1jFyMMgFBhXsYQXV2gFiwJR0GUQL7A5kPSaSbbTRSHD9%2b3OXj37FJ1Rs0JA%2bOt8p50HU%2fx8pE1WqklPK%2bm8y3xP0syHrhuIondeFSMGpEKZX392gj1C2rFPGDvZBXIaYJkdngxQbv9y%2bg5e7lIdH1uRHyUYC%2bHhLjtsmeRb36BaZGgRIG5IT6A2zWH2mnn9Ew799zv6i%2bGI1v%2fyZf8qInFhW4eKPbQa8G%2fVVvUY4XB3gc9DQrWm8LwLJmioxufnOQXeF02
# https://www.mercadopublico.cl/Procurement/Modules/Attachment/ViewAttachment.aspx?enc=flAJmJr7x%2bRNbpyFdPxErlTsgbcPbJ0B5MgcnreBjKM8k9WdB1kQ9ti84F1jFyMMgFBhXsYQXV2gFiwJR0GUQL7A5kPSaSbbTRSHD9%2b3OXj37FJ1Rs0JA%2bOt8p50HU%2fx8pE1WqklPK%2bm8y3xP0syHrhuIondeFSMGpEKZX392gj1C2rFPGDvZBXIaYJkdngxQbv9y%2bg5e7lIdH1uRHyUYC%2bHhLjtsmeRb36BaZGgRIG5IT6A2zWH2mnn9Ew799zv6i%2bGI1v%2fyZf8qInFhW4eKPbQa8G%2fVVvUY4XB3gc9DQrWm8LwLJmioxufnOQXeF02

# %%
session = requests.Session()

response_adj = session.get(url_adjuntos)
tree_adj = etree.fromstring(response_adj.text, parser)
print(etree.tostring(tree_adj, pretty_print=False, method='html'))
# Out:
# b'<html xmlns="http://www.w3.org/1999/xhtml">\r\n<head id="Head1"><title>\r\n\tVer anexos\r\n</title><link id="lnkStyleSheet" href="../../Includes/styles/ChileCompra.css" type="text/css" rel="stylesheet"> \r\n\t<script src="../../Includes/scripts/chilecompra.js" type="text/javascript"></script>   \r\n    <script src="../../Includes/scripts/JQuery/jquery-1.7.1.js" type="text/javascript"></script>\r\n\t<!-- Global Site Tag (gtag.js) - Google Analytics -->\r\n    <script async src="https://www.googletagmanager.com/gtag/js?id=UA-51338325-2"></script>\r\n    <script src="../../Includes/scripts/analytics.js" type="text/javascript"></script>\r\n    <script src="../../Includes/scripts/hotjar.js" type="text/javascript"></script>    \r\n</head>\r\n<body>\r\n   <form name="form1" method="post" action="./ViewAttachment.aspx?enc=flAJmJr7x%2bRNbpyFdPxErlTsgbcPbJ0B5MgcnreBjKM8k9WdB1kQ9ti84F1jFyMMgFBhXsYQXV2gFiwJR0GUQL7A5kPSaSbbTRSHD9%2b3OXj37FJ1Rs0JA%2bOt8p50HU%2fx8pE1WqklPK%2bm8y3xP0syHrhuIondeFSM
# ...

# %%
tabla_adjuntos:etree.ElementTree = tree_adj.find(".//body//table[@id='DWNL_grdId']")
print(tabla_adjuntos)
# Out:
# <Element table at 0x7d37281f0f00>

# %%
filas_adjuntos = tabla_adjuntos.getchildren()

def listar_adjuntos(lista_adjuntos):
  adjuntos = []
  for i in range(1, len(filas_adjuntos)):
      adjunto_td = filas_adjuntos[i][6] # Columna 6 corresponde a "Acciones" (la lupa para descargar archivo)
      adjunto_name = filas_adjuntos[i][1].find(".//span").text.strip() # Columna 1 corresponde a "Anexo"
      # Replace all spaces with _
      adjunto_name = re.sub(r'\s+', '_', adjunto_name)

      adjunto_search = adjunto_td.find(".//input[@type='image']").get("name")
      adjuntos.append({"adjunto_name": adjunto_name, "adjunto_search": adjunto_search})
  return adjuntos

# %%
print(listar_adjuntos(filas_adjuntos))
# Out:
# [{'adjunto_name': '1730142935191_ACTA_EVALUACION_EQUIPAMIENTO.pdf', 'adjunto_search': 'DWNL$grdId$ctl02$search'}, {'adjunto_name': '1731001882474_RES._EXENTA_N_834_DECLARA_DESIERTA_LICITACION.pdf', 'adjunto_search': 'DWNL$grdId$ctl03$search'}, {'adjunto_name': '1725303188073_MARCELA_MIRANDA.pdf', 'adjunto_search': 'DWNL$grdId$ctl04$search'}, {'adjunto_name': '1725303116253_ERIK_MORENO.pdf', 'adjunto_search': 'DWNL$grdId$ctl05$search'}, {'adjunto_name': '1725303207025_ALEJANDRO_GRIMAU.pdf', 'adjunto_search': 'DWNL$grdId$ctl06$search'}, {'adjunto_name': '1725303165877_IVAN_ROBLES.pdf', 'adjunto_search': 'DWNL$grdId$ctl07$search'}, {'adjunto_name': 'ACLARATORIA_4127-83-LR24.pdf', 'adjunto_search': 'DWNL$grdId$ctl08$search'}, {'adjunto_name': 'RES.EX.17131_DESGINA_COMISIÓN_4127-83-LR24.pdf', 'adjunto_search': 'DWNL$grdId$ctl09$search'}, {'adjunto_name': 'ANEXOS_EN_WORD_COMPUTADORES_37.000.000.000.docx', 'adjunto_search': 'DWNL$grdId$ctl10$search'}, {'adjunto_name': 'OF._E527503_RES._AF._
# ...

# %%
def descargar_adjuntos(tree_adj, lista_adj, session):
  view_state = tree_adj.find(".//input[@id='__VIEWSTATE']").get("value")
  view_state_generator = tree_adj.find(".//input[@id='__VIEWSTATEGENERATOR']").get("value")

  headers = {'User-Agent': 'Mozilla/5.0'}
  base_payload = {
  "__VIEWSTATE": view_state,
  "__VIEWSTATEGENERATOR": view_state_generator,
  }

  for adj in lista_adj:
    payload = base_payload.copy()
    payload[adj["adjunto_search"]+".x"] = "0"
    payload[adj["adjunto_search"]+".y"] = "0"
    response = session.post(url_adjuntos,headers=headers,data=payload)

    print(adj["adjunto_name"], response.status_code)
    if response.status_code != 200:
      continue
    with open(adj["adjunto_name"], "w+b") as f:
      # print response content length
      print("\tsize:", len(response.content))
      f.write(response.content)

# %%
# adjuntos = listar_adjuntos(filas_adjuntos)
# descargar_adjuntos(tree_adj, adjuntos, session)
# Out:
# 1730142935191_ACTA_EVALUACION_EQUIPAMIENTO.pdf 200
# 	size: 5700175
# 1731001882474_RES._EXENTA_N_834_DECLARA_DESIERTA_LICITACION.pdf 200
# 	size: 2428109
# 1725303188073_MARCELA_MIRANDA.pdf 200
# 	size: 195476
# 1725303116253_ERIK_MORENO.pdf 200
# 	size: 2119317
# 1725303207025_ALEJANDRO_GRIMAU.pdf 200
# 	size: 217560
# 1725303165877_IVAN_ROBLES.pdf 200
# 	size: 209021
# ACLARATORIA_4127-83-LR24.pdf 200
# 	size: 62707
# RES.EX.17131_DESGINA_COMISIÓN_4127-83-LR24.pdf 200
# 	size: 56708
# ANEXOS_EN_WORD_COMPUTADORES_37.000.000.000.docx 200
# 	size: 53016
# OF._E527503_RES._AF._N_07.pdf 200
# 	size: 103310
# RES._EFECTA_N_07_ANTECEDENTES.pdf 200
# 	size: 15679465
# RES._AFECTA_N_07_TOMADA_DE_RAZON.pdf 200
# 	size: 3294938
# None

# %% [markdown]
# ## Listar licitaciones

# %%
listar_session = requests.Session()
listar_url = "https://www.mercadopublico.cl/BuscarLicitacion/Home/Buscar"
listar_payload = {"textoBusqueda":"","idEstado":"5","codigoRegion":"-1","idTipoLicitacion":"25","fechaInicio":None,"fechaFin":None,"registrosPorPagina":"10","idTipoFecha":[],"idOrden":"1","compradores":[],"garantias":None,"rubros":[],"proveedores":[],"montoEstimadoTipo":[0],"esPublicoMontoEstimado":None,"pagina":0}
listar_response = listar_session.post(listar_url, data=listar_payload)
print(listar_response.text)
listar_tree = etree.fromstring(listar_response.text, parser)
# Out:
# <input type="hidden" id="hdnTotalPresupuestoPublico" name="hdnTotalPresupuestoPublico" value="333" />
# <input type="hidden" id="hdnTotalPresupuestoPrivado" name="hdnTotalPresupuestoPrivado" value="298" />
#     <div>
#             <div class="cabecera-resultados margin-bottom-lg row">
#                 <div class='col-md-6'>
#                     <div class="margin-bottom-xs">
#                         <span class='rot-resultado'>Se han encontrando</span><strong><span class='n-result'>631</span>resultados </strong><span class='rot-resultado'>para la búsqueda.</span>
#                     </div>
#                 </div>
#                 <div class="col-md-6">
#                     <div class="select-wrap esconder-cont">
#                         <div class="contenedor-ordenar">
#                             <label for="ordenarpor">Ordenar por </label>
#                             <select id="ordenarpor" name="ordenarpor" class="form-control"></select>
# ...

# %%
n_resultados = int(listar_tree.find(".//span[@class='n-result']").text.strip())
listar_resultados = []
print(n_resultados)
resultados_pag = listar_tree.findall(".//div[@class='responsive-resultado']")
print(len(resultados_pag))
for res in resultados_pag:
  id = res.find(".//span[@class='clearfix']").text.strip()
  url = res.find(".//div[@class='lic-block-body']//a").get("onclick")
  url = match.group(1) if (match := re.match(r".*\$.Busqueda.verFicha\('([^']+)'\).*", url)) else url
  print(id, url)
# Out:
# 631
# 10
# 1641-163-LR25 http://www.mercadopublico.cl/Procurement/Modules/RFB/DetailsAcquisition.aspx?idlicitacion=1641-163-LR25
# 621-460-LR25 http://www.mercadopublico.cl/Procurement/Modules/RFB/DetailsAcquisition.aspx?idlicitacion=621-460-LR25
# 621-442-LR25 http://www.mercadopublico.cl/Procurement/Modules/RFB/DetailsAcquisition.aspx?idlicitacion=621-442-LR25
# 621-453-LR25 http://www.mercadopublico.cl/Procurement/Modules/RFB/DetailsAcquisition.aspx?idlicitacion=621-453-LR25
# 621-473-LR25 http://www.mercadopublico.cl/Procurement/Modules/RFB/DetailsAcquisition.aspx?idlicitacion=621-473-LR25
# 621-474-LR25 http://www.mercadopublico.cl/Procurement/Modules/RFB/DetailsAcquisition.aspx?idlicitacion=621-474-LR25
# 1077920-10-LR25 http://www.mercadopublico.cl/Procurement/Modules/RFB/DetailsAcquisition.aspx?idlicitacion=1077920-10-LR25
# 621-449-LR25 http://www.mercadopublico.cl/Procurement/Modules/RFB/DetailsAcquisition.aspx?idlicitacion=621-449-LR25
# ...
